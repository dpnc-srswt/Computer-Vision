# %% [markdown]
# ## Computer Vision Basics Command

# %% [markdown]
# Mounting google drive

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My\ Drive/
# Out:
# /content/gdrive/My Drive

# %%
# Computer Vision is making computers learn from images. 
# Various operations like, image detection, recognition, image measurement can be applied.
# Library used for CV is openCV. Its pre installed in google colab.

# %% [markdown]
# Importing Libraries

# %%
import cv2
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Importing and displaying image

# %%
# Importing Image
img = cv2.imread('butterfly.jpg')
# Displaying picture using plt command
plt.imshow(img)

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying image using cv2_imshow() command. 
# This command is not directly available in Google colab, so importing "from google.colab.patches import cv2_imshow"
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=493x356 at 0x7F397427FA58>

# %% [markdown]
# Difference between image of both commands:
# the default setting of the color mode in OpenCV comes in the order of BGR, which is different from that of Matplotlib. Therefore to see the image in RGB mode, we need to convert it from BGR to RGB.

# %%
# Convert the image into RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# Convert the image into gray scale

# %%
# Convert the image into gray scale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap = 'gray')

# %%
# Plot the three channels of the image
fig, axs = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 20))
for i in range(0, 3):
    ax = axs[i]
    ax.imshow(img_rgb[:, :, i], cmap = 'gray')
plt.show()

# %%
# Transform the image into HSV and HLS models
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)

# Plot the converted images
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 15))
ax1.imshow(img_hsv)
ax2.imshow(img_hls) 
plt.show()

# %%
# Copy the image
img_copy = img.copy()
# Draw a rectangle 
cv2.rectangle(img_copy, pt1 = (100, 300), pt2 = (200, 250), 
              color = (255, 255, 0), thickness = 5) # CORDINATES OF UPPER LEFT POINT AND LOWER LEFT POINT
plt.imshow(img_copy)

# %%
# With cv2.circle() , we need to specify the point of its center and the length of its radius
# Draw a circle 
cv2.circle(img_copy, center = (200, 200), radius = 50, 
           color = (0, 0, 255), thickness = 5)
plt.imshow(img_copy)

# %%
# Add text 
cv2.putText(img_copy, text = "Butterfly", 
            org = (50, 50),
            fontFace = cv2.FONT_HERSHEY_DUPLEX, 
            fontScale = 2, 
            color = (0, 255, 0), 
            thickness = 2, 
            lineType = cv2.LINE_AA)
plt.imshow(img_copy)
